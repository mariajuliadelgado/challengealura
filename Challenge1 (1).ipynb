# %% [markdown]
# # Challange Data Science - Alura

# %% [markdown]
# ### Importando e organizando a base de dados

# %% [markdown]
# Na reunião inicial com as pessoas responsáveis pela área de vendas da empresa, foi explicada a importância de se **reduzir a Taxa de Evasão** de Clientes, conhecido como **Churn Rate**. Basicamente, o Churn Rate indica o quanto a empresa perdeu de receita ou clientes em um período de tempo.

# %%
import pandas as pd #importando o pandas

# %%
# importando a base de dados disponibilizada pela API da ALURA VOZ
base = 'https://raw.githubusercontent.com/sthemonica/alura-voz/main/Dados/Telco-Customer-Churn.json'
dados = pd.read_json(base)
dados.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %% [markdown]
# Extraindo  e normalizando os dados das colunas que apresentam o formato json.

# %%
# Extração coluna "customer"
dados_customer = pd.json_normalize(data=dados.customer)
dados_customer
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
# Extração coluna "phone"
dados_phone = pd.json_normalize(data=dados.phone)
dados_phone
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
# Extração coluna "internet"
dados_internet = pd.json_normalize(data=dados.internet)
dados_internet
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# 0            Yes              No
# 1             No             Yes
# 2             No              No
# 3            Yes             Yes
# 4            Yes              No
# ...          ...             ...
# 7262          No              No
# 7263          No             Yes
# 7264          No              No
# 7265          No             Yes
# 7266         Yes             Yes
#
# [7267 rows x 7 columns]

# %%
# Extração coluna "account"
dados_account = pd.json_normalize(data=dados.account)
dados_account
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# 3          1237.85
# 4            267.4
# ...            ...
# 7262         742.9
# 7263        1873.7
# 7264         92.75
# 7265       4627.65
# 7266        3707.6
#
# [7267 rows x 5 columns]

# %%
# listando os dados da coluna "churn"
dados_ch = list(dados['Churn'])
dados_ch = pd.DataFrame(dados_ch)
dados_ch
# Out:
#         0
# 0      No
# 1      No
# 2     Yes
# 3     Yes
# 4     Yes
# ...   ...
# 7262   No
# 7263  Yes
# 7264   No
# 7265   No
# 7266   No
#
# [7267 rows x 1 columns]

# %%
# listando os dados da coluna "customerID"
dados_id = list(dados['customerID'])
dados_id = pd.DataFrame(dados_id)
dados_id
# Out:
#                0
# 0     0002-ORFBO
# 1     0003-MKNFE
# 2     0004-TLHLJ
# 3     0011-IGKFF
# 4     0013-EXCHZ
# ...          ...
# 7262  9987-LUTYD
# 7263  9992-RRAMN
# 7264  9992-UJOEL
# 7265  9993-LHIEB
# 7266  9995-HOTOH
#
# [7267 rows x 1 columns]

# %%
# Concatenando as tabelas
dataset = pd.concat([dados_ch, dados_id, dados_customer, dados_phone, dados_internet, dados_account], axis = 1)
dataset.head(10)
# Out:
#      0           0  gender  SeniorCitizen Partner Dependents  tenure  \
# 0   No  0002-ORFBO  Female              0     Yes        Yes       9
# 1   No  0003-MKNFE    Male              0      No         No       9
# 2  Yes  0004-TLHLJ    Male              0      No         No       4
# 3  Yes  0011-IGKFF    Male              1     Yes         No      13
# 4  Yes  0013-EXCHZ  Female              1     Yes         No       3
# 5   No  0013-MHZWF  Female              0      No        Yes       9
# 6   No  0013-SMEOE  Female              1     Yes         No      71
# 7   No  0014-BMAQU    Male              0     Yes         No      63
# 8   No  0015-UOCOJ  Female              1      No         No       7
# 9   No  0016-QLJIS  Female              0     Yes        Yes      65
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
# 5          Yes            No             DSL  ...           No
# 6          Yes            No     Fiber optic  ...          Yes
# 7          Yes           Yes     Fiber optic  ...           No
# 8          Yes            No             DSL  ...           No
# 9          Yes           Yes             DSL  ...          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# 1               No          No          No             Yes  Month-to-month
# 2              Yes          No          No              No  Month-to-month
# 3              Yes          No         Yes             Yes  Month-to-month
# 4               No         Yes         Yes              No  Month-to-month
# 5               No         Yes         Yes             Yes  Month-to-month
# 6              Yes         Yes         Yes             Yes        Two year
# 7               No         Yes          No              No        Two year
# 8               No          No          No              No  Month-to-month
# 9              Yes         Yes         Yes             Yes        Two year
#
#   PaperlessBilling              PaymentMethod Charges.Monthly  Charges.Total
# 0              Yes               Mailed check           65.60          593.3
# 1               No               Mailed check           59.90          542.4
# 2              Yes           Electronic check           73.90         280.85
# 3              Yes           Electronic check           98.00        1237.85
# 4              Yes               Mailed check           83.90          267.4
# 5              Yes    Credit card (automatic)           69.40         571.45
# 6              Yes  Bank transfer (automatic)          109.70        7904.25
# 7              Yes    Credit card (automatic)           84.65         5377.8
# 8              Yes           Electronic check           48.20         340.35
# 9              Yes               Mailed check           90.45         5957.9
#
# [10 rows x 21 columns]

# %%
# Renomeando as colunas
dataset.columns = ["churn", "id", "genero", "idoso", "parceiro", "dependentes", "Meses_adesao", "servico_telefone", "outras_linhas_telefonicas", "servico_internet", "seguranca_online", "backup_online", "protecao_dispositivo", "suporte_tecnico", "servico_tv", "servico_streaming", "contrato", "pagamento_digital", "metodo_pagamento", "cobranca_mensal", "cobranca_total"] 
dataset.head()
# Out:
#   churn          id  genero  idoso parceiro dependentes  Meses_adesao  \
# 0    No  0002-ORFBO  Female      0      Yes         Yes             9
# 1    No  0003-MKNFE    Male      0       No          No             9
# 2   Yes  0004-TLHLJ    Male      0       No          No             4
# 3   Yes  0011-IGKFF    Male      1      Yes          No            13
# 4   Yes  0013-EXCHZ  Female      1      Yes          No             3
#
#   servico_telefone outras_linhas_telefonicas servico_internet  ...  \
# 0              Yes                        No              DSL  ...
# 1              Yes                       Yes              DSL  ...
# 2              Yes                        No      Fiber optic  ...
# 3              Yes                        No      Fiber optic  ...
# 4              Yes                        No      Fiber optic  ...
#
#   backup_online protecao_dispositivo suporte_tecnico servico_tv  \
# 0           Yes                   No             Yes        Yes
# 1            No                   No              No         No
# 2            No                  Yes              No         No
# 3           Yes                  Yes              No        Yes
# 4            No                   No             Yes        Yes
#
#   servico_streaming        contrato pagamento_digital  metodo_pagamento  \
# 0                No        One year               Yes      Mailed check
# 1               Yes  Month-to-month                No      Mailed check
# 2                No  Month-to-month               Yes  Electronic check
# 3               Yes  Month-to-month               Yes  Electronic check
# 4                No  Month-to-month               Yes      Mailed check
#
#   cobranca_mensal  cobranca_total
# 0            65.6           593.3
# 1            59.9           542.4
# 2            73.9          280.85
# 3            98.0         1237.85
# 4            83.9           267.4
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Verificando e tratando os dados das colunas que possuem valores vazios e/ou nulos.

# %%
# Informações do DataFrame
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   churn                      7267 non-null   object
#  1   id                         7267 non-null   object
#  2   genero                     7267 non-null   object
#  3   idoso                      7267 non-null   int64
#  4   parceiro                   7267 non-null   object
#  5   dependentes                7267 non-null   object
#  6   Meses_adesao               7267 non-null   int64
#  7   servico_telefone           7267 non-null   object
#  8   outras_linhas_telefonicas  7267 non-null   object
#  9   servico_internet           7267 non-null   object
#  10  seguranca_online           7267 non-null   object
#  11  backup_online              7267 non-null   object
#  12  protecao_dispositivo       7267 non-null   object
#  13  suporte_tecnico            7267 non-null   object
#  14  servico_tv                 7267 non-null   object
#  15  servico_streaming          7267 non-null   object
#  16  contrato                   7267 non-null   object
#  17  pagamento_digital          7267 non-null   object
#  18  metodo_pagamento           7267 non-null   object
#  19  cobranca_mensal            7267 non-null   float64
#  20  cobranca_total             7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB

# %%
# Dados NAN
dataset[dataset.isna()].count()
# Out:
# churn                        0
# id                           0
# genero                       0
# idoso                        0
# parceiro                     0
# dependentes                  0
# Meses_adesao                 0
# servico_telefone             0
# outras_linhas_telefonicas    0
# servico_internet             0
# seguranca_online             0
# backup_online                0
# protecao_dispositivo         0
# suporte_tecnico              0
# servico_tv                   0
# servico_streaming            0
# contrato                     0
# pagamento_digital            0
# metodo_pagamento             0
# cobranca_mensal              0
# cobranca_total               0
# dtype: int64

# %%
# Verificando valores vazios
dataset[dataset == ' '].count()
# Out:
# churn                         0
# id                            0
# genero                        0
# idoso                         0
# parceiro                      0
# dependentes                   0
# Meses_adesao                  0
# servico_telefone              0
# outras_linhas_telefonicas     0
# servico_internet              0
# seguranca_online              0
# backup_online                 0
# protecao_dispositivo          0
# suporte_tecnico               0
# servico_tv                    0
# servico_streaming             0
# contrato                      0
# pagamento_digital             0
# metodo_pagamento              0
# cobranca_mensal               0
# cobranca_total               11
# dtype: int64

# %%
dataset[dataset == ''].count()
# Out:
# churn                        224
# id                             0
# genero                         0
# idoso                          0
# parceiro                       0
# dependentes                    0
# Meses_adesao                   0
# servico_telefone               0
# outras_linhas_telefonicas      0
# servico_internet               0
# seguranca_online               0
# backup_online                  0
# protecao_dispositivo           0
# suporte_tecnico                0
# servico_tv                     0
# servico_streaming              0
# contrato                       0
# pagamento_digital              0
# metodo_pagamento               0
# cobranca_mensal                0
# cobranca_total                 0
# dtype: int64

# %%
dataset.query("cobranca_total == ' '")
# Out:
#      churn          id  genero  idoso parceiro dependentes  Meses_adesao  \
# 975     No  1371-DWPAZ  Female      0      Yes         Yes             0
# 1775    No  2520-SGTTA  Female      0      Yes         Yes             0
# 1955    No  2775-SEFEE    Male      0       No         Yes             0
# 2075    No  2923-ARZLG    Male      0      Yes         Yes             0
# 2232    No  3115-CZMZD    Male      0       No         Yes             0
# 2308    No  3213-VVOLG    Male      0      Yes         Yes             0
# 2930    No  4075-WKNIU  Female      0      Yes         Yes             0
# 3134    No  4367-NUYAO    Male      0      Yes         Yes             0
# 3203    No  4472-LVYGI  Female      0      Yes         Yes             0
# 4169    No  5709-LVOEQ  Female      0      Yes         Yes             0
# 5599    No  7644-OMVMY    Male      0      Yes         Yes             0
#
#      servico_telefone outras_linhas_telefonicas servico_internet  ...  \
# 975                No          No phone service              DSL  ...
# 1775              Yes                        No               No  ...
# 1955              Yes                       Yes              DSL  ...
# 2075              Yes                        No               No  ...
# 2232              Yes                        No               No  ...
# 2308              Yes                       Yes               No  ...
# 2930              Yes                       Yes              DSL  ...
# 3134              Yes                       Yes               No  ...
# 3203               No          No phone service              DSL  ...
# 4169              Yes                        No              DSL  ...
# 5599              Yes                        No               No  ...
#
#             backup_online protecao_dispositivo      suporte_tecnico  \
# 975                   Yes                  Yes                  Yes
# 1775  No internet service  No internet service  No internet service
# 1955                  Yes                   No                  Yes
# 2075  No internet service  No internet service  No internet service
# 2232  No internet service  No internet service  No internet service
# 2308  No internet service  No internet service  No internet service
# 2930                  Yes                  Yes                  Yes
# 3134  No internet service  No internet service  No internet service
# 3203                   No                  Yes                  Yes
# 4169                  Yes                  Yes                   No
# 5599  No internet service  No internet service  No internet service
#
#                servico_tv    servico_streaming  contrato pagamento_digital  \
# 975                   Yes                   No  Two year                No
# 1775  No internet service  No internet service  Two year                No
# 1955                   No                   No  Two year               Yes
# 2075  No internet service  No internet service  One year               Yes
# 2232  No internet service  No internet service  Two year                No
# 2308  No internet service  No internet service  Two year                No
# 2930                  Yes                   No  Two year                No
# 3134  No internet service  No internet service  Two year                No
# 3203                  Yes                   No  Two year               Yes
# 4169                  Yes                  Yes  Two year                No
# 5599  No internet service  No internet service  Two year                No
#
#                metodo_pagamento cobranca_mensal  cobranca_total
# 975     Credit card (automatic)           56.05
# 1775               Mailed check           20.00
# 1955  Bank transfer (automatic)           61.90
# 2075               Mailed check           19.70
# 2232               Mailed check           20.25
# 2308               Mailed check           25.35
# 2930               Mailed check           73.35
# 3134               Mailed check           25.75
# 3203  Bank transfer (automatic)           52.55
# 4169               Mailed check           80.85
# 5599               Mailed check           19.85
#
# [11 rows x 21 columns]

# %%
# Preencher com '0' as cobranças vazias
dataset['cobranca_total'].replace(' ', 0, inplace=True)

# %%
#Alterando o tipo de dado da coluna "cobranca_total" para float.
dataset['cobranca_total'] = dataset['cobranca_total'].astype('float')

# %%
# Informações da coluna target "churn"
dataset['churn'].value_counts()
# Out:
# No     5174
# Yes    1869
#         224
# Name: churn, dtype: int64

# %%
# Trocando os 224 valores vazios por "Sem informação"
dataset['churn'].replace('', 'Sem informação', inplace=True)
dataset['churn'].value_counts()
# Out:
# No                5174
# Yes               1869
# Sem informação     224
# Name: churn, dtype: int64

# %% [markdown]
# ### Visualizando os dados relacionando com variável Churn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# GRÁFICO DE BARRAS

sns.countplot(x='churn', data=dataset, palette='mako')
plt.ylabel('Valores')
plt.title('Análise Churn')
# Out:
# Text(0.5, 1.0, 'Análise Churn')

# %%
# GRÁFICO DE PIZZA

plt.figure
plt.title('Análise Churn')
dataset['churn'].value_counts().plot(kind='pie', autopct='%.2f%%')

# %%
#  "yes" corresponde aos ativos e "no" cancelados

# %%
# HISTOGRAMA MESES DE ADESÃO X CHURN

fig = sns.displot(data=dataset, x='Meses_adesao', col='churn', hue='churn', palette='viridis')
plt.show(fig)

# %%
# Podemos perceber que a maior parte dos clientes costumam cancelar o plano nos primeiros 5 meses de adesão

# %%
# GRÁFICO DE BARRAS CHURN X GENERO

ax = sns.countplot(x="churn", hue="genero", data=dataset, palette='mako')
plt.title('Churn x Gênero')
# Out:
# Text(0.5, 1.0, 'Churn x Gênero')

# %%
# O gênero não está relacionado aos cancelamentos

# %%
# GRÁFICO DE BARRAS CHURN X DEPENDENTES

ax = sns.countplot(x="churn", hue="dependentes", data=dataset, palette='mako')
plt.title('Churn x Dependentes')
# Out:
# Text(0.5, 1.0, 'Churn x Dependentes')

# %%
# Pessoas sem dependentes cancelam mais o plano

# %%
# GRÁFICO DE BARRAS CHURN X SERVIÇO DE INTERNET

ax = sns.countplot(x="churn", hue="servico_internet", data=dataset, palette='mako')
plt.title('Churn x Serviço de Internet')
# Out:
# Text(0.5, 1.0, 'Churn x Serviço de Internet')

# %%
# Pessoas com internet de fibra óptica são mais propensas a cancelar

# %%
# GRÁFICO DE BARRAS CHURN X SERVIÇO DE TV A CABO

ax = sns.countplot(x="churn", hue="servico_tv", data=dataset, palette='mako')
plt.title('Churn x Serviço de TV a cabo')
# Out:
# Text(0.5, 1.0, 'Churn x Serviço de TV a cabo')

# %%
# GRÁFICO DE BARRAS CHURN X MÉTODO DE PAGAMENTO

ax = sns.countplot(x="churn", hue="metodo_pagamento", data=dataset, palette='mako')
plt.title('Churn x Método de pagamento')
# Out:
# Text(0.5, 1.0, 'Churn x Método de pagamento')

# %%
# A maior parte do cancelamentos vem de pessoas que optaram pelo método de cheque eletrônico

# %%
# GRÁFICO DE BARRAS CHURN X PROTEÇÃO DISPOSITIVO

ax = sns.countplot(x="churn", hue="protecao_dispositivo", data=dataset, palette='mako')
plt.title('Churn x Proteção dispositivo')
# Out:
# Text(0.5, 1.0, 'Churn x Proteção dispositivo')

# %%
# Pessoas que não possuem proteção dispositivo cancelam mais o plano

# %%
# GRÁFICO DE BARRAS CHURN X SUPORTE TÉCNICO

ax = sns.countplot(x="churn", hue="suporte_tecnico", data=dataset, palette='mako')
plt.title('Churn x Suporte Técnico')
# Out:
# Text(0.5, 1.0, 'Churn x Suporte Técnico')

# %%
# As pessoas que não contatam o suporte técnico são mais propensas a cancelar o plano

# %%
# GRÁFICO DE BARRAS CHURN X SEGURANÇA ONLINE

ax = sns.countplot(x="churn", hue="seguranca_online", data=dataset, palette='mako')
plt.title('Churn x Segurança Online')
# Out:
# Text(0.5, 1.0, 'Churn x Segurança Online')

# %%
# Existem mais cancelamentos no grupo de pessoas que não possuem segurança online

# %% [markdown]
# ### Correlação

# %%
# Informações do DataFrame
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   churn                      7267 non-null   object
#  1   id                         7267 non-null   object
#  2   genero                     7267 non-null   object
#  3   idoso                      7267 non-null   int64
#  4   parceiro                   7267 non-null   object
#  5   dependentes                7267 non-null   object
#  6   Meses_adesao               7267 non-null   int64
#  7   servico_telefone           7267 non-null   object
#  8   outras_linhas_telefonicas  7267 non-null   object
#  9   servico_internet           7267 non-null   object
#  10  seguranca_online           7267 non-null   object
#  11  backup_online              7267 non-null   object
#  12  protecao_dispositivo       7267 non-null   object
#  13  suporte_tecnico            7267 non-null   object
#  14  servico_tv                 7267 non-null   object
#  15  servico_streaming          7267 non-null   object
#  16  contrato                   7267 non-null   object
#  17  pagamento_digital          7267 non-null   object
#  18  metodo_pagamento           7267 non-null   object
#  19  cobranca_mensal            7267 non-null   float64
#  20  cobranca_total             7267 non-null   float64
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.2+ MB

# %%
# Variáveis do tipo objeto não são lidas na correlação

# %%
dataset.select_dtypes(include=object).columns
# Out:
# Index(['churn', 'id', 'genero', 'parceiro', 'dependentes', 'servico_telefone',
#        'outras_linhas_telefonicas', 'servico_internet', 'seguranca_online',
#        'backup_online', 'protecao_dispositivo', 'suporte_tecnico',
#        'servico_tv', 'servico_streaming', 'contrato', 'pagamento_digital',
#        'metodo_pagamento'],
#       dtype='object')

# %%
#Convertendo para categórico
for i in ['churn', 'id', 'genero', 'parceiro', 'dependentes', 'servico_telefone',
       'outras_linhas_telefonicas', 'servico_internet', 'seguranca_online',
       'backup_online', 'protecao_dispositivo', 'suporte_tecnico',
       'servico_tv', 'servico_streaming', 'contrato', 'pagamento_digital',
       'metodo_pagamento']:
    dataset[i] = dataset[i].astype('category')
dataset.dtypes
# Out:
# churn                        category
# id                           category
# genero                       category
# idoso                           int64
# parceiro                     category
# dependentes                  category
# Meses_adesao                    int64
# servico_telefone             category
# outras_linhas_telefonicas    category
# servico_internet             category
# seguranca_online             category
# backup_online                category
# protecao_dispositivo         category
# suporte_tecnico              category
# servico_tv                   category
# servico_streaming            category
# contrato                     category
# pagamento_digital            category
# metodo_pagamento             category
# cobranca_mensal               float64
# cobranca_total                float64
# dtype: object

# %%
#Convertendo para inteiro
for i in ['churn', 'id', 'genero', 'parceiro', 'dependentes', 'servico_telefone',
       'outras_linhas_telefonicas', 'servico_internet', 'seguranca_online',
       'backup_online', 'protecao_dispositivo', 'suporte_tecnico',
       'servico_tv', 'servico_streaming', 'contrato', 'pagamento_digital',
       'metodo_pagamento']:
    dataset[i] = dataset[i].cat.codes
dataset.dtypes
# Out:
# churn                           int8
# id                             int16
# genero                          int8
# idoso                          int64
# parceiro                        int8
# dependentes                     int8
# Meses_adesao                   int64
# servico_telefone                int8
# outras_linhas_telefonicas       int8
# servico_internet                int8
# seguranca_online                int8
# backup_online                   int8
# protecao_dispositivo            int8
# suporte_tecnico                 int8
# servico_tv                      int8
# servico_streaming               int8
# contrato                        int8
# pagamento_digital               int8
# metodo_pagamento                int8
# cobranca_mensal              float64
# cobranca_total               float64
# dtype: object

# %%
correlation = dataset.corr()
correlation
# Out:
#                               churn        id    genero     idoso  parceiro  \
# churn                      1.000000 -0.014863 -0.007448  0.148432 -0.146341
# id                        -0.014863  1.000000  0.005205 -0.004454 -0.022487
# genero                    -0.007448  0.005205  1.000000 -0.004288 -0.005007
# idoso                      0.148432 -0.004454 -0.004288  1.000000  0.022970
# parceiro                  -0.146341 -0.022487 -0.005007  0.022970  1.000000
# dependentes               -0.160281 -0.010729  0.012038 -0.212952  0.448900
# Meses_adesao              -0.345607  0.006448  0.005765  0.018187  0.377551
# servico_telefone           0.010881 -0.007620 -0.005073  0.010060  0.018828
# outras_linhas_telefonicas  0.037469  0.002820 -0.006544  0.147433  0.141172
# servico_internet          -0.044752 -0.012679  0.000627 -0.032584  0.002271
# seguranca_online          -0.284129  0.011895 -0.014821 -0.127660  0.148932
# backup_online             -0.191600 -0.003437 -0.011617 -0.011327  0.150955
# protecao_dispositivo      -0.175520 -0.007791  0.000006 -0.020565  0.165611
# suporte_tecnico           -0.277400  0.003646 -0.006573 -0.150126  0.122670
# servico_tv                -0.035855 -0.006859 -0.006347  0.028770  0.137397
# servico_streaming         -0.037696 -0.016524 -0.010795  0.046279  0.127679
# contrato                  -0.390222  0.012266 -0.002009 -0.140570  0.292189
# pagamento_digital          0.189174  0.001136 -0.011273  0.157734 -0.011201
# metodo_pagamento           0.105814  0.013407  0.019876 -0.039769 -0.154357
# cobranca_mensal            0.188562 -0.003744 -0.013889  0.220388  0.097122
# cobranca_total            -0.194826  0.000450  0.000367  0.104076  0.315409
#
#                            dependentes  Meses_adesao  servico_telefone  \
# churn                        -0.160281     -0.345607          0.010881
# id                           -0.010729      0.006448         -0.007620
# genero                        0.012038      0.005765         -0.005073
# idoso                        -0.212952      0.018187          0.010060
# parceiro                      0.448900      0.377551          0.018828
# dependentes                   1.000000      0.159892         -0.003863
# Meses_adesao                  0.159892      1.000000          0.010205
# servico_telefone             -0.003863      0.010205          1.000000
# outras_linhas_telefonicas    -0.027847      0.342276         -0.020485
# servico_internet              0.046072     -0.027409          0.389422
# seguranca_online              0.156633      0.326456         -0.015054
# backup_online                 0.092327      0.373016          0.024831
# protecao_dispositivo          0.082739      0.373238          0.002381
# suporte_tecnico               0.134135      0.321691         -0.019846
# servico_tv                    0.049840      0.291474          0.052862
# servico_streaming             0.022134      0.298701          0.042914
# contrato                      0.241781      0.672170          0.003306
# pagamento_digital            -0.111752      0.007949          0.013624
# metodo_pagamento             -0.039463     -0.369311         -0.002500
# cobranca_mensal              -0.115832      0.247982          0.246709
# cobranca_total                0.061474      0.825407          0.113985
#
#                            outras_linhas_telefonicas  servico_internet  ...  \
# churn                                       0.037469         -0.044752  ...
# id                                          0.002820         -0.012679  ...
# genero                                     -0.006544          0.000627  ...
# idoso                                       0.147433         -0.032584  ...
# parceiro                                    0.141172          0.002271  ...
# dependentes                                -0.027847          0.046072  ...
# Meses_adesao                                0.342276         -0.027409  ...
# servico_telefone                           -0.020485          0.389422  ...
# outras_linhas_telefonicas                   1.000000         -0.108899  ...
# servico_internet                           -0.108899          1.000000  ...
# seguranca_online                            0.007511         -0.026260  ...
# backup_online                               0.120577          0.035914  ...
# protecao_dispositivo                        0.124007          0.046697  ...
# suporte_tecnico                             0.009026         -0.024368  ...
# servico_tv                                  0.176338          0.106868  ...
# servico_streaming                           0.182075          0.099792  ...
# contrato                                    0.111505          0.102013  ...
# pagamento_digital                           0.165752         -0.142358  ...
# metodo_pagamento                           -0.175795          0.086033  ...
# cobranca_mensal                             0.433995         -0.323743  ...
# cobranca_total                              0.452253         -0.174696  ...
#
#                            backup_online  protecao_dispositivo  \
# churn                          -0.191600             -0.175520
# id                             -0.003437             -0.007791
# genero                         -0.011617              0.000006
# idoso                          -0.011327             -0.020565
# parceiro                        0.150955              0.165611
# dependentes                     0.092327              0.082739
# Meses_adesao                    0.373016              0.373238
# servico_telefone                0.024831              0.002381
# outras_linhas_telefonicas       0.120577              0.124007
# servico_internet                0.035914              0.046697
# seguranca_online                0.187781              0.176301
# backup_online                   1.000000              0.191151
# protecao_dispositivo            0.191151              1.000000
# suporte_tecnico                 0.193375              0.239405
# servico_tv                      0.147892              0.280609
# servico_streaming               0.138831              0.289258
# contrato                        0.280343              0.350333
# pagamento_digital              -0.010443             -0.038668
# metodo_pagamento               -0.122715             -0.133181
# cobranca_mensal                 0.120399              0.163711
# cobranca_total                  0.377390              0.389620
#
#                            suporte_tecnico  servico_tv  servico_streaming  \
# churn                            -0.277400   -0.035855          -0.037696
# id                                0.003646   -0.006859          -0.016524
# genero                           -0.006573   -0.006347          -0.010795
# idoso                            -0.150126    0.028770           0.046279
# parceiro                          0.122670    0.137397           0.127679
# dependentes                       0.134135    0.049840           0.022134
# Meses_adesao                      0.321691    0.291474           0.298701
# servico_telefone                 -0.019846    0.052862           0.042914
# outras_linhas_telefonicas         0.009026    0.176338           0.182075
# servico_internet                 -0.024368    0.106868           0.099792
# seguranca_online                  0.286312    0.045580           0.058422
# backup_online                     0.193375    0.147892           0.138831
# protecao_dispositivo              0.239405    0.280609           0.289258
# suporte_tecnico                   1.000000    0.161297           0.161746
# servico_tv                        0.161297    1.000000           0.432225
# servico_streaming                 0.161746    0.432225           1.000000
# contrato                          0.424022    0.226908           0.231028
# pagamento_digital                -0.115912    0.095616           0.082670
# metodo_pagamento                 -0.104904   -0.106233          -0.112628
# cobranca_mensal                  -0.009453    0.335324           0.335724
# cobranca_total                    0.274476    0.392776           0.399560
#
#                            contrato  pagamento_digital  metodo_pagamento  \
# churn                     -0.390222           0.189174          0.105814
# id                         0.012266           0.001136          0.013407
# genero                    -0.002009          -0.011273          0.019876
# idoso                     -0.140570           0.157734         -0.039769
# parceiro                   0.292189          -0.011201         -0.154357
# dependentes                0.241781          -0.111752         -0.039463
# Meses_adesao               0.672170           0.007949         -0.369311
# servico_telefone           0.003306           0.013624         -0.002500
# outras_linhas_telefonicas  0.111505           0.165752         -0.175795
# servico_internet           0.102013          -0.142358          0.086033
# seguranca_online           0.373697          -0.157604         -0.097620
# backup_online              0.280343          -0.010443         -0.122715
# protecao_dispositivo       0.350333          -0.038668         -0.133181
# suporte_tecnico            0.424022          -0.115912         -0.104904
# servico_tv                 0.226908           0.095616         -0.106233
# servico_streaming          0.231028           0.082670         -0.112628
# contrato                   1.000000          -0.175893         -0.228207
# pagamento_digital         -0.175893           1.000000         -0.063304
# metodo_pagamento          -0.228207          -0.063304          1.000000
# cobranca_mensal           -0.075613           0.353714         -0.191070
# cobranca_total             0.445447           0.160023         -0.327894
#
#                            cobranca_mensal  cobranca_total
# churn                             0.188562       -0.194826
# id                               -0.003744        0.000450
# genero                           -0.013889        0.000367
# idoso                             0.220388        0.104076
# parceiro                          0.097122        0.315409
# dependentes                      -0.115832        0.061474
# Meses_adesao                      0.247982        0.825407
# servico_telefone                  0.246709        0.113985
# outras_linhas_telefonicas         0.433995        0.452253
# servico_internet                 -0.323743       -0.174696
# seguranca_online                 -0.052997        0.254127
# backup_online                     0.120399        0.377390
# protecao_dispositivo              0.163711        0.389620
# suporte_tecnico                  -0.009453        0.274476
# servico_tv                        0.335324        0.392776
# servico_streaming                 0.335724        0.399560
# contrato                         -0.075613        0.445447
# pagamento_digital                 0.353714        0.160023
# metodo_pagamento                 -0.191070       -0.327894
# cobranca_mensal                   1.000000        0.652211
# cobranca_total                    0.652211        1.000000
#
# [21 rows x 21 columns]

# %%
# matriz de correlação
plt.figure(figsize=(14,14))
plot = sns.heatmap(correlation, annot = True, fmt=".1f", linewidths=.6, cmap='mako')
plot

# %%
# Podemos perceber que a correlação entre as variáveis estão próximos a zero. Desse modo, as variações entre as variáveis não influenciam uma as outras.

# %% [markdown]
# # Considerações

# %% [markdown]
# Durante a análise podemos perceber que cerca de 25% dos usuários cancelaram o plano. Sendo que o maior número de cancelamento se dá até 5 meses de adesão. As pessoas que possuem internet fibra óptica, que pagam pela modalidade cheque eltrônico, não possuem proteção ao dispositivo,que não contatam ao suporte técnico e não possuem segurança online são mais propensas a cancelar.
